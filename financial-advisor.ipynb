# %%
# Step 1: Install LangChain
# %pip install langchain
# %pip install langchain-community

# %%
from langchain_community.llms import Ollama

llm = Ollama(model="llama2")

# %%
llm.invoke("how can langsmith help with testing?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llm.invoke("how can langsmith help with testing?")
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_core\language_models\llms.py:385, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     375 def invoke(
#     376     self,
#     377     input: LanguageModelInput,
#    (...)
#     381     **kwargs: Any,
#     382 ) -> str:
#     383     config = ensure_config(config)
#     384     return (
# --> 385         self.generate_prompt(
#     386             [self._convert_input(input)],
#     387             stop=stop,
#     388             callbacks=config.get("callbacks"),
#     389             tags=config.get("tags"),
#     390             metadata=config.get("metadata"),
#     391             run_name=config.get("run_name"),
#     392             run_id=config.pop("run_id", None),
#     393             **kwargs,
#     394         )
#     395         .generations[0][0]
#     396         .text
#     397     )
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_core\language_models\llms.py:750, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     742 def generate_prompt(
#     743     self,
#     744     prompts: List[PromptValue],
#    (...)
#     747     **kwargs: Any,
#     748 ) -> LLMResult:
#     749     prompt_strings = [p.to_string() for p in prompts]
# --> 750     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_core\language_models\llms.py:944, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     929 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     930     run_managers = [
#     931         callback_manager.on_llm_start(
#     932             dumpd(self),
#    (...)
#     942         )
#     943     ]
# --> 944     output = self._generate_helper(
#     945         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     946     )
#     947     return output
#     948 if len(missing_prompts) > 0:
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_core\language_models\llms.py:787, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     785     for run_manager in run_managers:
#     786         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 787     raise e
#     788 flattened_outputs = output.flatten()
#     789 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_core\language_models\llms.py:774, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     764 def _generate_helper(
#     765     self,
#     766     prompts: List[str],
#    (...)
#     770     **kwargs: Any,
#     771 ) -> LLMResult:
#     772     try:
#     773         output = (
# --> 774             self._generate(
#     775                 prompts,
#     776                 stop=stop,
#     777                 # TODO: support multiple run managers
#     778                 run_manager=run_managers[0] if run_managers else None,
#     779                 **kwargs,
#     780             )
#     781             if new_arg_supported
#     782             else self._generate(prompts, stop=stop)
#     783         )
#     784     except BaseException as e:
#     785         for run_manager in run_managers:
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_community\llms\ollama.py:429, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     427 generations = []
#     428 for prompt in prompts:
# --> 429     final_chunk = super()._stream_with_aggregation(
#     430         prompt,
#     431         stop=stop,
#     432         images=images,
#     433         run_manager=run_manager,
#     434         verbose=self.verbose,
#     435         **kwargs,
#     436     )
#     437     generations.append([final_chunk])
#     438 return LLMResult(generations=generations)
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_community\llms\ollama.py:347, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     338 def _stream_with_aggregation(
#     339     self,
#     340     prompt: str,
#    (...)
#     344     **kwargs: Any,
#     345 ) -> GenerationChunk:
#     346     final_chunk: Optional[GenerationChunk] = None
# --> 347     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     348         if stream_resp:
#     349             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_community\llms\ollama.py:192, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     184 def _create_generate_stream(
#     185     self,
#     186     prompt: str,
#    (...)
#     189     **kwargs: Any,
#     190 ) -> Iterator[str]:
#     191     payload = {"prompt": prompt, "images": images}
# --> 192     yield from self._create_stream(
#     193         payload=payload,
#     194         stop=stop,
#     195         api_url=f"{self.base_url}/api/generate",
#     196         **kwargs,
#     197     )
#
# File d:\codes\financial-advisor\venv\Lib\site-packages\langchain_community\llms\ollama.py:271, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     269     else:
#     270         optional_detail = response.text
# --> 271         raise ValueError(
#     272             f"Ollama call failed with status code {response.status_code}."
#     273             f" Details: {optional_detail}"
#     274         )
#     275 return response.iter_lines(decode_unicode=True)
#
# ValueError: Ollama call failed with status code 500. Details: {"error":"model requires more system memory (8.4 GiB) than is available (6.8 GiB)"}

# %%
llm.invoke("Tell me 10 uniquies things of Cambodia!")
# Out:
# '\n Sure, here are 10 unique things about Cambodia:\n\n1. Angkor Wat - The largest religious monument in the world, built in the 12th century as a Hindu temple dedicated to the god Vishnu.\n2. The Khmer Rouge Regime - In the 1970s, the Khmer Rouge regime was responsible for the deaths of an estimated 1.7 to 2.2 million people, out of a population of approximately 8 million, through forced labor, mass executions, and starvation.\n3. The Tonle Sap Lake - The largest freshwater lake in Southeast Asia, covering over 26,000 square kilometers and providing a vital source of food and income for millions of Cambodians.\n4. The Royal Palace - A complex of buildings that serves as the official residence of the King of Cambodia, including the Throne Hall, the Moonlight Pavilion, and the Silver Pagoda.\n5. The Killing Fields - A memorial site dedicated to the victims of the Khmer Rouge regime, where thousands of people were killed and buried in mass graves.\n6. The Cambodian language - A member of the Austroasiatic language family, spoken by over 16 million people worldwide, including more than 90% of the population of Cambodia.\n7. The Angkor Archaeological Park - A UNESCO World Heritage Site that covers an area of over 400 square kilometers and includes numerous ancient temples, monuments, and ruins.\n8. The Battambang Province - Known for its beautiful landscapes, traditional villages, and colonial-era architecture, including the Wat Kor Temple and the Phnom Sampeu Cave.\n9. The Cambodian cuisine - Influenced by Thai, Vietnamese, and Chinese cooking styles, with popular dishes such as fish amok (a fish dish cooked in coconut milk and spices), nom banh chok (a rice noodle dish), and grilled meat skewers.\n10. The Cambodian culture - Rich in tradition and history, including the use of offerings, incense, and chanting in religious ceremonies, as well as the importance of family, community, and respect for elders.'

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a world class technical documentation writer."),
    ("user", "{input}")
])
